# %% [markdown]
# # Systematic Investment Final Project
# ### 2019 NYU Stern Spring Semester
#
# #### Principal Investigators: Ruijie (Cherry) Cai (rc3470),  Zhiyu Chen (zc987) <br> Email: ruijiu.cai@stern.nyu.edu, zhiyu.chen@stern.nyu.edu

# %% [markdown]
# ## Result Visualization

# %%
import numpy as np                          # foundation for pandas 
import pandas as pd                         # data package
import matplotlib.pyplot as plt             # graphics module

# %%
plot = pd.read_excel('sensitivity_analysis.xlsx').set_index("Tested Period (yr)")

# %%
plot
# Out:
#                     zdiff5  zdiff10  zdiff20  period matched  \
# Tested Period (yr)
# 2010-2019             0.24     0.00    -0.29         -1.9491
# 2011-2019             0.13    -0.12    -0.28         -2.2130
# 2012-2019            -0.01    -0.08    -0.23         -1.8895
# 2013-2019             0.06     0.04    -0.13         -1.1215
# 2014-2019             0.38     0.30    -0.09         -0.1772
# 2015-2019             0.07     0.09    -0.25         -1.3125
# 2016-2019             0.12     0.27    -0.41         -0.8027
# 2017-2019             0.48     0.76    -0.29         -0.0600
# 2018-2019            -0.01     1.90     0.17          2.3180
#
#                     fixed train period(9yr)  fixed predict period(1yr)
# Tested Period (yr)
# 2010-2019                           -1.9491                     0.0055
# 2011-2019                           -1.9652                     1.3693
# 2012-2019                           -2.4833                     1.5456
# ...

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2,figsize = (22,6))

ax1.plot(plot.index, plot["zdiff5"], color = "blue")
ax1.plot(plot.index, plot["zdiff10"], color = "blue")
ax1.plot(plot.index, plot["zdiff20"],color = "blue")
ax1.plot(plot.index, plot["period matched"],color = "red")

ax2.plot(plot.index, plot["fixed train period(9yr)"], color = "blue")
ax2.plot(plot.index, plot["fixed predict period(1yr)"], color = "red")

ax1.spines["right"].set_visible(False)
ax1.spines["top"].set_visible(False)

ax2.spines["right"].set_visible(False)
ax2.spines["top"].set_visible(False)

ax1.set_xlabel("Tested Period (yr)",fontsize = 12)
ax2.set_xlabel("Tested Period (yr)",fontsize = 12)
ax1.set_ylabel("Sharpe Ratio",fontsize = 12)

ax1.legend(loc='upper left',frameon=True,fontsize = 12)
ax2.legend(loc='upper left',frameon=True,fontsize = 12)

ax1.axvline(x= "2010-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax1.axvline(x= "2011-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax1.axvline(x= "2012-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax1.axvline(x= "2013-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax1.axvline(x= "2014-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax1.axvline(x= "2015-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax1.axvline(x= "2016-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax1.axvline(x= "2017-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax1.axvline(x= "2018-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 

ax2.axvline(x= "2010-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax2.axvline(x= "2011-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax2.axvline(x= "2012-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax2.axvline(x= "2013-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax2.axvline(x= "2014-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax2.axvline(x= "2015-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax2.axvline(x= "2016-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax2.axvline(x= "2017-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
ax2.axvline(x= "2018-2019", color='k',alpha=0.2, linestyle='--', linewidth=2) 
plt.show()
# Here we download the graph
#fig.savefig('Avg Housing Price In Different Tier Cities.png')
